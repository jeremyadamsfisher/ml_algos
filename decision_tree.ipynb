# %%
import numpy as np
import sklearn.datasets as ds
from sklearn.model_selection import train_test_split

# %%
ddf = ds.load_boston()
features = ddf["feature_names"]
X = ddf["data"]
y = ddf["target"]
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=0.33, random_state=42)

# %%
thresholds = []
for i, _ in enumerate(features):
    feature_train = X_train[:,i]
    for threshold in np.unique(feature):
        cost = (
            (feature_train[feature_train<=threshold].mean() - y_train[feature_train<=threshold].mean())**2
            + (feature_train[feature_train>threshold].mean() - y_train[feature_train>threshold].mean())**2
        )
        if cost is not np.nan:
            thresholds.append((cost, threshold, _))
min(thresholds, key=lambda x: x[0])
# Out:
# /Users/jeremyfisher/miniconda3/envs/crunch/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: Mean of empty slice.
#
# /Users/jeremyfisher/miniconda3/envs/crunch/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: Mean of empty slice.
#   import sys
# (nan, 0.00632, 'CRIM')

# %%
thresholds
# Out:
# [(933.2558276334089, 0.00632),
#  (1145.7411086666432, 0.00906),
#  (1035.343509610339, 0.01096),
#  (1123.4224251014855, 0.01301),
#  (1209.5826004191988, 0.01311),
#  (1111.5218792756464, 0.0136),
#  (1296.1186461478874, 0.01381),
#  (1301.7272077931505, 0.01432),
#  (1288.974392246561, 0.01439),
#  (1361.065105978295, 0.01501),
#  (1424.6202914120242, 0.01538),
#  (1409.7937923169363, 0.01709),
#  (1409.8405811389362, 0.01778),
#  (1368.2042154985422, 0.0187),
#  (1370.9618989667279, 0.01951),
#  (1326.0540125102827, 0.01965),
#  (1389.601193752787, 0.02009),
#  (1362.9309760205047, 0.02055),
#  (1394.2780844540757, 0.02177),
#  (1388.8725066398583, 0.02187),
#  (1342.4311274653141, 0.02498),
#  (1320.4868015235743, 0.02543),
#  (1327.8763709435107, 0.02729),
#  (1302.714218749869, 0.02731),
#  (1300.9350094869214, 0.02763),
#  (1286.3418103219046, 0.02875),
#  (1276.2306600489633, 0.02899),
#  (1271.0856488850993, 0.02985),
#  (1246.3320519963152, 0.03041),
# ...

# %%
for feature in features:
    feature_vec = df[feature].sort_values()
    solutions = []
    for value in feature_vec:

# %%
list(feature_vec)

# %%
X.index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-44419fa61e38> in <module>
# ----> 1 X.index
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'
